# %%
import pandas as pd

# %%
df = pd.read_csv("./data/stations/modified_stations.csv")

# %%
df.head()
# Out:
#             id  latitude  longitude  elevation state                   name  \
# 0  ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# 1  ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# 2  AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# 3  AEM00041194   25.2550    55.3640       10.4   NaN             DUBAI INTL
# 4  AEM00041217   24.4330    54.6510       26.8   NaN         ABU DHABI INTL
#
#   gsn_flag hcn_crn_flag   wmo_id
# 0      NaN          NaN      NaN
# 1      NaN          NaN      NaN
# 2      GSN          NaN  41196.0
# 3      NaN          NaN  41194.0
# 4      NaN          NaN  41217.0

# %%
rows_with_empty_id = df[df['id'] == ""]
rows_with_empty_id
# Out:
# Empty DataFrame
# Columns: [id, latitude, longitude, elevation, state, name, gsn_flag, hcn_crn_flag, wmo_id]
# Index: []

# %%
import psycopg2

def populate_db():
    try:
        # Connect to your postgres DB
        connection = psycopg2.connect(
            dbname="mydatabase",
            user="myuser",
            password="mypassword",
            host="localhost",  # Connect to the host where Docker is running
            port="5432"
        )
        cursor = connection.cursor()

        # print(df.head())

        cursor.execute('''
                    CREATE TABLE IF NOT EXISTS Station (
                        id VARCHAR(100) PRIMARY KEY,
                        latitude FLOAT,
                        longitude FLOAT,
                        elevation FLOAT,
                        state VARCHAR(100),
                        name VARCHAR(100),
                        gsn_flag VARCHAR(100),
                        hcn_crn_flag VARCHAR(100),
                        wmo_id VARCHAR(100)
                    )
                ''')
        
        for index, row in df.iterrows():
            cursor.execute('''
                INSERT INTO Station 
                           (
                            id,
                            latitude,
                            longitude,
                            elevation,
                            state,
                            name,
                            gsn_flag,
                            hcn_crn_flag,
                            wmo_id
                           ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
            ''', (
                row['id'], row['latitude'],row['longitude'],row['elevation'], 
                row['state'],row['name'],row['gsn_flag'],row['hcn_crn_flag'],row['wmo_id']))

        # Commit changes
        connection.commit()

    except Exception as error:
        print(f"Error: {error}")
    
    finally:
        if connection:
            cursor.close()
            connection.close()

if __name__ == "__main__":
    populate_db()

# %%
try:
    # Connect to your postgres DB
    connection = psycopg2.connect(
        dbname="mydatabase",
        user="myuser",
        password="mypassword",
        host="localhost",  # Connect to the host where Docker is running
        port="5432"
    )
    cursor = connection.cursor()

    # print(df.head())

    res = cursor.execute('''
                SELECT COUNT(*) FROM Station
            ''')
    print("Test")
    print(res)

except Exception as error:
    print(f"Error: {error}")

finally:
    if connection:
        cursor.close()
        connection.close()
# Out:
# Test
# None

# %%
# from database.models import Station
# for index, row in df.iterrows():
#     obj = Station(
#         id=row['id'],
#         latitude=row['latitude'],
#         longitude=row['longitude'],
#         elevation=row['elevation'],
#         state=row['state'],
#         name=row['name'],
#         gsn_flag=row['gsn_flag'],
#         hcn_crn_flag=row['hcn_crn_flag'],
#         wmo_id=row['wmo_id'],
#         # assign other fields accordingly
#     )
#     obj.save()
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from database.models import Station
#       2 for index, row in df.iterrows():
#       3     obj = Station(
#       4         id=row['id'],
#       5         latitude=row['latitude'],
#    (...)
#      13         # assign other fields accordingly
#      14     )
#
# File c:\Users\Fabi\dev\python\ESDP1-Database-Project\nceiDatabase\database\models.py:5
#       1 from django.db import models
#       4 # Create your models here.
# ----> 5 class Station(models.Model):
#       6     GSN_FLAGS = [
#       7         ('', 'non-GSN station or WMO Station number not available'),
#       8         ('GSN', 'GSN station'),
#       9     ]
#      11     HCN_CRN_FLAGS = [
#      12         ('', 'Not a member of the U.S. Historical Climatology or U.S. Climate Reference Networks'),
#      13         ('HCN', 'U.S. Historical Climatology Network station'),
#      14         ('CRN', 'U.S. Climate Reference Network or U.S. Regional Climate Network Station'),
#      15     ]
#
# File c:\Python312\Lib\site-packages\django\db\models\base.py:129, in ModelBase.__new__(cls, name, bases, attrs, **kwargs)
#     126 app_label = None
#     128 # Look for an application configuration to attach the model to.
# --> 129 app_config = apps.get_containing_app_config(module)
#     131 if getattr(meta, "app_label", None) is None:
#     132     if app_config is None:
#
# File c:\Python312\Lib\site-packages\django\apps\registry.py:260, in Apps.get_containing_app_config(self, object_name)
#     251 def get_containing_app_config(self, object_name):
#     252     """
#     253     Look for an app config containing a given object.
#     254
#    (...)
#     258     Return None if the object isn't in any registered app config.
#     259     """
# --> 260     self.check_apps_ready()
#     261     candidates = []
#     262     for app_config in self.app_configs.values():
#
# File c:\Python312\Lib\site-packages\django\apps\registry.py:137, in Apps.check_apps_ready(self)
#     132 from django.conf import settings
#     134 # If "not ready" is due to unconfigured settings, accessing
#     135 # INSTALLED_APPS raises a more helpful ImproperlyConfigured
#     136 # exception.
# --> 137 settings.INSTALLED_APPS
#     138 raise AppRegistryNotReady("Apps aren't loaded yet.")
#
# File c:\Python312\Lib\site-packages\django\conf\__init__.py:89, in LazySettings.__getattr__(self, name)
#      87 """Return the value of a setting and cache it in self.__dict__."""
#      88 if (_wrapped := self._wrapped) is empty:
# ---> 89     self._setup(name)
#      90     _wrapped = self._wrapped
#      91 val = getattr(_wrapped, name)
#
# File c:\Python312\Lib\site-packages\django\conf\__init__.py:69, in LazySettings._setup(self, name)
#      67 if not settings_module:
#      68     desc = ("setting %s" % name) if name else "settings"
# ---> 69     raise ImproperlyConfigured(
#      70         "Requested %s, but settings are not configured. "
#      71         "You must either define the environment variable %s "
#      72         "or call settings.configure() before accessing settings."
#      73         % (desc, ENVIRONMENT_VARIABLE)
#      74     )
#      76 self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting INSTALLED_APPS, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
